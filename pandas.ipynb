# %% [markdown]
# ### This file merges variable name file with shaply file, and variable value and crisis dummy
#
# ### a. and add base and final rows to each country and year
#
# ### b. also ***(vertically)*** merges with metadata (country group, year group) using their group averages
#
# ### c. merge with crisis dummy files

# %%
import os
import pandas as pd
import numpy as np
import matplotlib

# load and merge
data_dir = '../datasets'

df_shap = pd.read_excel(os.path.join(data_dir, 'shapvalues_norm_full.xlsx'))
df_varname = pd.read_excel(os.path.join(data_dir, 'mapping variable labels.xlsx'))
df_country_type = pd.read_excel(os.path.join(data_dir, 'mapping country group.xlsx'))
df_value = pd.read_excel(os.path.join(data_dir, 'variable_full.xlsx'))
df_crisis = pd.read_excel(os.path.join(data_dir, 'mapping precrisis.xlsx'))


df_shap.drop(columns=['avg','norm_shap'], inplace= True)

# %% [markdown]
# #### merge shap with varname

# %%
df_new = pd.merge(df_shap, df_varname, left_index= True, right_on= 'Variable', how= 'left')
df_new.reset_index(inplace= True)
df_new.tail()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ec016aa2eadb> in <module>
# ----> 1 df_new = pd.merge(df_shap, df_varname, right_on= 'Variable', how= 'left')
#       2 df_new.reset_index(inplace= True)
#       3 df_new.tail()
#
# D:\data\ve_upgrade_fin\_PyEnvsSPR_backup\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# D:\data\ve_upgrade_fin\_PyEnvsSPR_backup\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     522             warnings.warn(msg, UserWarning)
#     523
# --> 524         self._validate_specification()
#     525
#     526         # note this function has side effects
#
# D:\data\ve_upgrade_fin\_PyEnvsSPR_backup\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1055                                      'of levels in the index of "left"')
#    1056                 self.left_on = [None] * n
# -> 1057         if len(self.right_on) != len(self.left_on):
#    1058             raise ValueError("len(right_on) must equal len(left_on)")
#    1059
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# #### add base and tootal as new variables

# %%
# reshape to wide
df_new = df_new[['year','country','Label','shap']]

df_new = pd.pivot_table(df_new, values ='shap', index =['country','year'], columns = 'Label')

df_new.reset_index(inplace= True)

# %%
# add base and total rows
df_new['base'] = 50

df_new['total']=df_new[df_new.columns.tolist()[2:]].apply(sum, axis = 1)

df_new['total'].plot.hist()

# %%
# reshape to long
df_new = df_new.melt(id_vars=['country','year'], value_vars=df_new.columns.tolist()[2:], var_name='Variable', value_name='shap')
df_new.head()
# Out:
#                 country  year             Variable      shap
# 0  Afghanistan, I.S. of  1980  3-month T-Bill rate  2.851679
# 1  Afghanistan, I.S. of  1981  3-month T-Bill rate  2.882570
# 2  Afghanistan, I.S. of  1982  3-month T-Bill rate -0.553009
# 3  Afghanistan, I.S. of  1983  3-month T-Bill rate -0.022255
# 4  Afghanistan, I.S. of  1984  3-month T-Bill rate -0.437330

# %% [markdown]
# #### Add variable value column

# %%
# add column for "variable value" from file
df_value = df_value[['country','year','Variable','variable value']]
df_value.head()
# Out:
#                 country  year             Variable  variable value
# 0  Afghanistan, I.S. of  1980  3-month T-Bill rate        0.000000
# 1  Afghanistan, I.S. of  1981  3-month T-Bill rate        0.000000
# 2  Afghanistan, I.S. of  1982  3-month T-Bill rate       11.100833
# 3  Afghanistan, I.S. of  1983  3-month T-Bill rate        8.944167
# 4  Afghanistan, I.S. of  1984  3-month T-Bill rate        9.897500

# %% [markdown]
# #### Add country & year group averages rows

# %%
df_value.loc[df_value['variable value'] == 0, 'variable value'] = np.nan # set 0 to nan
df_new = pd.merge(df_new, df_value, left_on = ['country','year','Variable'], right_on = ['country','year','Variable'], how= 'left')

# %%
# merge with country group
df_group = pd.merge(df_new, df_country_type, left_on= 'country', right_on= 'country', how = 'left')
df_group.reset_index(inplace = True)

df_group.head()
# Out:
#    index               country  year             Variable      shap  \
# 0      0  Afghanistan, I.S. of  1980  3-month T-Bill rate  2.851679
# 1      1  Afghanistan, I.S. of  1981  3-month T-Bill rate  2.882570
# 2      2  Afghanistan, I.S. of  1982  3-month T-Bill rate -0.553009
# 3      3  Afghanistan, I.S. of  1983  3-month T-Bill rate -0.022255
# 4      4  Afghanistan, I.S. of  1984  3-month T-Bill rate -0.437330
#
#    variable value  Oil exporters Income
# 0             NaN              0    LIC
# 1             NaN              0    LIC
# 2       11.100833              0    LIC
# 3        8.944167              0    LIC
# 4        9.897500              0    LIC

# %%
# aggregate by country income group
df_income_group = df_group.groupby(['Income','year','Variable']).agg({'shap':'mean', 'variable value': 'mean'})
df_income_group.reset_index(inplace= True)

df_income_group.rename({'Income' : 'country'}, axis = 1, inplace= True)
df_income_group.head()
# Out:
#   country  year               Variable  variable value      shap
# 0      AE  1980    3-month T-Bill rate             NaN  2.502182
# 1      AE  1980       Bank PD, average             NaN -0.318967
# 2      AE  1980  Banking Claims to GDP             NaN -2.134330
# 3      AE  1980         Cap Adeq Ratio             NaN -0.958507
# 4      AE  1980      Corp Debt, Sub IG             NaN  1.769560

# %%
# aggregate by oil group
df_oil_group = df_group.groupby(['Oil exporters','year','Variable']).agg({'shap':'mean', 'variable value': 'mean'})
df_oil_group.reset_index(inplace= True)
df_oil_group.rename({'Oil exporters' : 'country'}, axis = 1, inplace= True)

df_oil_group.country = df_oil_group.country.apply(lambda x: 'oil-exporter' if x == 1 else 'non-oil exporter')
df_oil_group.head()

## append country group averages to original table
df_full = pd.concat([df_group, df_income_group, df_oil_group], axis = 0, sort = True)

# %%
df_group.head()
# Out:
#    index               country  year             Variable      shap  \
# 0      0  Afghanistan, I.S. of  1980  3-month T-Bill rate  2.851679
# 1      1  Afghanistan, I.S. of  1981  3-month T-Bill rate  2.882570
# 2      2  Afghanistan, I.S. of  1982  3-month T-Bill rate -0.553009
# 3      3  Afghanistan, I.S. of  1983  3-month T-Bill rate -0.022255
# 4      4  Afghanistan, I.S. of  1984  3-month T-Bill rate -0.437330
#
#    variable value  Oil exporters Income
# 0             NaN              0    LIC
# 1             NaN              0    LIC
# 2       11.100833              0    LIC
# 3        8.944167              0    LIC
# 4        9.897500              0    LIC

# %%
# merge with year group
year_cut = [1989, 1999, 2004, 2009, 2015]
year_range = ['1980-1989','1990-1999','2000-2004','2005-2009','2010-2015','2016-Present']

df_full['year_group'] = df_full.year.apply(lambda x: year_range[len([1 for y in year_cut if y < x])] )

#a = 1990
#year_range[len([1 for x in year_cut if x < a])]

# aggregate by year group
df_year_group = df_full.groupby(['year_group','country','Variable']).agg({'shap':'mean', 'variable value': 'mean'})
df_year_group.reset_index(inplace= True)
df_year_group.rename({'year_group':'year'}, axis= 1, inplace= True)
df_year_group.head()
# Out:
#         year country               Variable  variable value      shap
# 0  1980-1989      AE    3-month T-Bill rate        8.133542  1.536329
# 1  1980-1989      AE       Bank PD, average             NaN -0.235396
# 2  1980-1989      AE  Banking Claims to GDP             NaN -1.891135
# 3  1980-1989      AE         Cap Adeq Ratio             NaN -1.022442
# 4  1980-1989      AE      Corp Debt, Sub IG             NaN  1.734175

# %%
## append everything
df_full = pd.concat([df_full, df_year_group], axis = 0, sort = True)

# %%
df_full = df_full[['year','country','Variable', 'shap','variable value']]

# %% [markdown]
# #### calculate rank on shaply values

# %%
# create rank on shap value (for ranking)
df_full['rank'] = None
df_full.loc[df_full['Variable'] == 'total','rank'] = 30
df_full.loc[df_full['Variable'] == 'base','rank'] = 0

df_full.loc[(df_full['Variable'] != 'base') & (df_full['Variable'] != 'total'),'rank'] = \
df_full.loc[(df_full['Variable'] != 'base') & (df_full['Variable'] != 'total')].groupby(['country','year'])['shap'].rank(ascending= False)

df_full[(df_full['country'] =='China') & (df_full['year']==2018)].sort_values('rank')

# create rank on shap absolute value (for filtering)
df_full['shap_abs'] = abs(df_full.shap)

df_full['rank_abs'] = None
df_full.loc[(df_full['Variable'] != 'base') & (df_full['Variable'] != 'total'),'rank_abs'] = \
df_full.loc[(df_full['Variable'] != 'base') & (df_full['Variable'] != 'total')].groupby(['country','year'])['shap_abs'].rank(ascending= False)

df_full.tail()
# Out:
#                year       country             Variable       shap  \
# 36823  2016-Present  oil-exporter  Real Deposit Growth  -0.517820
# 36824  2016-Present  oil-exporter   Real Output Growth   0.408381
# 36825  2016-Present  oil-exporter    Total Debt Growth  -0.140766
# 36826  2016-Present  oil-exporter                 base  50.000000
# 36827  2016-Present  oil-exporter                total  18.302694
#
#        variable value rank   shap_abs rank_abs
# 36823       -0.118176   18   0.517820       13
# 36824        0.943793    3   0.408381       18
# 36825        0.144633   12   0.140766       24
# 36826             NaN    0  50.000000     None
# 36827             NaN   30  18.302694     None

# %%
df_full = df_full[['year','country','Variable','shap','variable value','rank','rank_abs']]
df_full.head()
# Out:
#    year               country             Variable      shap  variable value  \
# 0  1980  Afghanistan, I.S. of  3-month T-Bill rate  2.851679             NaN
# 1  1981  Afghanistan, I.S. of  3-month T-Bill rate  2.882570             NaN
# 2  1982  Afghanistan, I.S. of  3-month T-Bill rate -0.553009       11.100833
# 3  1983  Afghanistan, I.S. of  3-month T-Bill rate -0.022255        8.944167
# 4  1984  Afghanistan, I.S. of  3-month T-Bill rate -0.437330        9.897500
#
#   rank rank_abs
# 0    3        5
# 1    2        4
# 2   19       17
# 3   17       29
# 4   20       17

# %% [markdown]
# #### merge with crisis dummy

# %%
df_crisis.year = df_crisis.year.astype(str)
df_full.year = df_full.year.astype(str)

# %%
df_crisis[~df_crisis.country_name.isin(df_full.country.tolist())].country_name.value_counts()
# Out:
# São Tomé and Príncipe    31
# Côte d'Ivoire            31
# Syria                    27
# Name: country_name, dtype: int64

# %%
df_full = pd.merge(df_full, df_crisis, left_on= ['year','country'], right_on= ['year','country_name'], how = 'left')

# %% [markdown]
# #### save files

# %%
df_full.to_excel(os.path.join(data_dir,'shaply_for_tableau_harry_v4.xlsx'))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-20-adf2e012d6a9> in <module>()
# ----> 1 df_full.to_excel(os.path.join(data_dir,'shaply_for_tableau_harry_v4.xlsx'))
#
# ~\AppData\Local\conda\conda\envs\py35\lib\site-packages\pandas\core\frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1764         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1765                         startcol=startcol, freeze_panes=freeze_panes,
# -> 1766                         engine=engine)
#    1767
#    1768     def to_stata(self, fname, convert_dates=None, write_index=True,
#
# ~\AppData\Local\conda\conda\envs\py35\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     652                            freeze_panes=freeze_panes)
#     653         if need_save:
# --> 654             writer.save()
#
# ~\AppData\Local\conda\conda\envs\py35\lib\site-packages\pandas\io\excel.py in save(self)
#    1730         """
#    1731
# -> 1732         return self.book.close()
#    1733
#    1734     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0,
#
# ~\AppData\Local\conda\conda\envs\py35\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     304         if not self.fileclosed:
#     305             self.fileclosed = 1
# --> 306             self._store_workbook()
#     307
#     308     def set_size(self, width, height):
#
# ~\AppData\Local\conda\conda\envs\py35\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     653
#     654         xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 655                             allowZip64=self.allow_zip64)
#     656
#     657         # Add XML sub-files to the Zip file with their Excel filename.
#
# ~\AppData\Local\conda\conda\envs\py35\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1007             while True:
#    1008                 try:
# -> 1009                     self.fp = io.open(file, filemode)
#    1010                 except OSError:
#    1011                     if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: '../datasets\\shaply_for_tableau_harry_v4.xlsx'

# %%
## df_new[(df_new['year'] >= 2016)  & (df_new['Variable'] == 'total')]['shap'].mean()
